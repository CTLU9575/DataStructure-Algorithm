# %% [markdown]
# #### 1.Leetcode第70题，爬楼梯
# 三种解法：\
# \
# 1.普通的递归\
# 2.带一个hashmap的递归，python不会写\
# 3.循环的方式，斐波那契数列

# %%
# 70.1 普通的递归，超出时间限制
# 递归的算法分析方法！！！

class Solution:
    def climbStairs(self, n: int) -> int:
        if n == 1:
            return 1
        elif n==2:
            return 2
        else:
            return self.climbStairs(n-1) + self.climbStairs(n-2)

# %%
# how to use hash_map in python!!!
# 70.2 hash_map的方式(感觉不是)，用了dict，hash_map的递归
# 执行用时：32 ms, 在所有 Python3 提交中击败了82.75%的用户
# 内存消耗：14.7 MB, 在所有 Python3 提交中击败了97.16%的用户

class Solution:
    def climbStairs(self, n: int) -> int:
        hash_map = {}
        hash_map[1] = 1
        hash_map[2] = 2
        for i in range(3, n+1):
            hash_map[i] = hash_map[i-1]+hash_map[i-2]
        return hash_map[n]

# %%
# 70.3 循环，自底向上累加
# 执行用时：32 ms, 在所有 Python3 提交中击败了82.75%的用户
# 内存消耗：14.9 MB, 在所有 Python3 提交中击败了33.43%的用户

class Solution:
    def climbStairs(self, n: int) -> int:
        pre, current = 0, 1
        for i in range(n):
            current, pre = current + pre, current
        return current

# %%
# 剑指offer第10题 斐波那契数列

# %%
# Leetcode 1.1 两数之和，穷举法
# 执行用时：3140 ms, 在所有 Python3 提交中击败了24.97%的用户
# 内存消耗：15.5 MB, 在所有 Python3 提交中击败了77.52%的用户
# 时间复杂度O(n^2)

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        for i in range(len(nums)-1):
            for j in range(i+1, len(nums)):
                if nums[i]+nums[j] == target:
                    return [i, j]
                else:
                    continue
        return [0, 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-736ad756738b> in <module>
#       3 # 内存消耗：15.5 MB, 在所有 Python3 提交中击败了77.52%的用户
#       4
# ----> 5 class Solution:
#       6     def twoSum(self, nums: List[int], target: int) -> List[int]:
#       7         for i in range(len(nums)-1):
#
# <ipython-input-2-736ad756738b> in Solution()
#       4
#       5 class Solution:
# ----> 6     def twoSum(self, nums: List[int], target: int) -> List[int]:
#       7         for i in range(len(nums)-1):
#       8             for j in range(i+1, len(nums)):
#
# NameError: name 'List' is not defined

# %%
# Leetcode 1.2 两数之和，使用了hashmap
# 执行用时：44 ms, 在所有 Python3 提交中击败了60.57%的用户
# 内存消耗：15.9 MB, 在所有 Python3 提交中击败了40.93%的用户
# 时间复杂度O(n)

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        hash_map = {}
        for i in range(len(nums)):
            if target - nums[i] in hash_map.keys():
                return [i, hash_map[target - nums[i]]]
            else:
                hash_map[nums[i]] = i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3c839d8c997e> in <module>
#       3 # 内存消耗：15.9 MB, 在所有 Python3 提交中击败了40.93%的用户
#       4
# ----> 5 class Solution:
#       6     def twoSum(self, nums: List[int], target: int) -> List[int]:
#       7         hash_map = {}
#
# <ipython-input-3-3c839d8c997e> in Solution()
#       4
#       5 class Solution:
# ----> 6     def twoSum(self, nums: List[int], target: int) -> List[int]:
#       7         hash_map = {}
#       8         for i in range(len(nums)):
#
# NameError: name 'List' is not defined

# %%
# Leetcode 88.1 合并有序数组，使用了内置函数,对nums1的赋值的写法表示不理解？？？
# 执行用时：36 ms, 在所有 Python3 提交中击败了66.92%的用户
# 内存消耗：14.8 MB, 在所有 Python3 提交中击败了97.47%的用户
# # 时间复杂度O(m+n)log(m+n)，快速排序

class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        """
        Do not return anything, modify nums1 in-place instead.
        """
        nums1[m:] = nums2
        nums1.sort()

class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        """
        Do not return anything, modify nums1 in-place instead.
        """
        nums1[:] = nums1[:m] + nums2
        nums1.sort()

# %%
# Leetcode 88.2 合并有序数组，双指针
# 执行用时：32 ms, 在所有 Python3 提交中击败了86.69%的用户
# 内存消耗：14.8 MB, 在所有 Python3 提交中击败了93.61%的用户
# 时间复杂度O(m+n), 空间复杂度O(m+n)

class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        """
        Do not return anything, modify nums1 in-place instead.
        """
        i = 0
        j = 0
        temp = []
        while i < m or j < n:
            if i >= m:
                temp.append(nums2[j])
                j+=1
            elif j >= n:
                temp.append(nums1[i])
                i+=1
            elif nums1[i] < nums2[j]:
                temp.append(nums1[i])
                i +=1
            else:
                temp.append(nums2[j])
                j+=1
        nums1[:] = temp

# %%
# Leetcode 88.3 合并有序数组，双指针，不开辟临时数组
# 执行用时：32 ms, 在所有 Python3 提交中击败了86.69%的用户
# 内存消耗：14.9 MB, 在所有 Python3 提交中击败了63.86%的用户
# 时间复杂度O(m+n), 空间复杂度O(1)

class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        i = m-1
        j = n-1
        while j >= 0:
            if i+1 == 0 or nums2[j] >= nums1[i]:
                nums1[i+j+1] = nums2[j]
                j-=1
            else:
                nums1[i+j+1] = nums1[i]
                i-=1

# %%
# Leetcode 283 移动零，双指针，不开辟临时数组
# 执行用时：52 ms, 在所有 Python3 提交中击败了60.14%的用户
# 内存消耗：15.9 MB, 在所有 Python3 提交中击败了28.70%的用户
# 时间复杂度O(n), 空间复杂度O(1)

class Solution:
    def moveZeroes(self, nums: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        p1 = 0
        p2 = 0
        while p1 < len(nums):
            if nums[p1] != 0:
                nums[p2] = nums[p1]
                p1 += 1
                p2 += 1
            else:
                p1 += 1
        while p2 < len(nums):
            nums[p2] = 0
            p2 += 1

# %%
# Leetcode 448 找到数组中所有消失的数字
# 执行用时：92 ms, 在所有 Python3 提交中击败了45.23%的用户， 71.58
# 内存消耗：21.1 MB, 在所有 Python3 提交中击败了77.11%的用户，78.13
# 时间复杂度O(n), 空间复杂度O(1)

# enumerate:可以用来返回list的索引和值 和 [(表达式) for index, value in enumerate(list_type) if (条件)]

class Solution:
    def findDisappearedNumbers(self, nums: List[int]) -> List[int]:
        result = []
        n = len(nums)
        for i in range(n):
            nums[(nums[i]-1) % n] += n
        for i in range(n):
            if nums[i] < n+1:
                result.append(i + 1)
        return result

# 官方解：enumerate，多用了几个变量！！
class Solution:
    def findDisappearedNumbers(self, nums: List[int]) -> List[int]:
        n = len(nums)
        for num in nums:
            x = (num - 1) % n
            nums[x] += n
        
        ret = [i + 1 for i, num in enumerate(nums) if num <= n]
        return ret

# %% [markdown]
# #### part 2 链表部分

# %%
# Leetcode 21.1 合并2个有序链表，类似双指针的方法，链表属实没搞明白..
# 执行用时：40 ms, 在所有 Python3 提交中击败了62.86%的用户
# 内存消耗：15 MB, 在所有 Python3 提交中击败了40.39%的用户
# 时间复杂度O(m+n), 空间复杂度O(1)


# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
        result = dummy = ListNode(0)
        
        while list1 and list2:
            if list1.val < list2.val:
                dummy.next = list1
                list1 = list1.next
            else:
                dummy.next = list2
                list2 = list2.next
            dummy = dummy.next
        if list1:
            dummy.next = list1
        if list2:
            dummy.next = list2
        
        return result.next

# %%
# Leetcode 21.1 合并2个有序链表，递归的方法，官方解答，搞的不太明白
# 执行用时：44 ms, 在所有 Python3 提交中击败了36.39%的用户
# 内存消耗：15 MB, 在所有 Python3 提交中击败了23.85%的用户
# 时间复杂度O(m+n), 空间复杂度O(m+n)

class Solution:
    def mergeTwoLists(self, l1: ListNode, l2: ListNode) -> ListNode:
        if l1 is None:
            return l2
        elif l2 is None:
            return l1
        elif l1.val < l2.val:
            l1.next = self.mergeTwoLists(l1.next, l2)
            return l1
        else:
            l2.next = self.mergeTwoLists(l1, l2.next)
            return l2

# %%
# Leetcode 83.1 删除链表中的重复元素
# 执行用时：48 ms, 在所有 Python3 提交中击败了35.40%的用户
# 内存消耗：15 MB, 在所有 Python3 提交中击败了44.86%的用户
# 时间复杂度O(n), 空间复杂度O(1)

# if not current or not current.next: return head: 这句话很重要！！不然老显示什么nonetype error

class Solution:
    def deleteDuplicates(self, head: ListNode) -> ListNode:
        current = head
        if not current or not current.next:
            return head
        while current.next:
            if current.val == current.next.val:
                current.next = current.next.next
            else:
                current = current.next
        return head

# %%
# Leetcode 83.1 删除链表中的重复元素, 递归的方法，又被递归搞懵了
# 执行用时：52 ms, 在所有 Python3 提交中击败了14.61%的用户
# 内存消耗：14.9 MB, 在所有 Python3 提交中击败了90.78%的用户
# 时间复杂度O(n)

class Solution:
    def deleteDuplicates(self, head: ListNode) -> ListNode:
        if not head or not head.next: return head
        head.next = self.deleteDuplicates(head.next)
        return head.next if head.val == head.next.val else head

# %%
# Leetcode 141 环形链表
# 执行用时：52 ms, 在所有 Python3 提交中击败了87.25%的用户
# 内存消耗：18.7 MB, 在所有 Python3 提交中击败了24.31%的用户
# 时间复杂度O(n), 空间复杂度O(1)

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def hasCycle(self, head: Optional[ListNode]) -> bool:
        if not head:
            return False
        p1, p2 = head, head
        while p2.next and p2.next.next: # 这句话很关键
            p1 = p1.next
            p2 = p2.next.next
            if p1 == p2:
                return True
        return False

# %% [markdown]
# 算法流程：\
# 双指针第一次相遇： 设两指针 fast，slow 指向链表头部 head，fast 每轮走 2 步，slow 每轮走 1 步；\
#
# **第一种结果：** fast 指针走过链表末端，说明链表无环，直接返回 null；
#
# TIPS: 若有环，两指针一定会相遇。因为每走 1 轮，fast 与 slow 的间距 +1，fast 终会追上 slow；\
# **第二种结果：** 当fast == slow时， 两指针在环中 第一次相遇 。下面分析此时fast 与 slow走过的 步数关系 ：
#
# 设链表共有 a+b 个节点，其中 链表头部到链表入口 有 a 个节点（不计链表入口节点）， 链表环 有 b 个节点（这里需要注意，a 和 b 是未知数，例如图解上链表 a=4 , b=5）；设两指针分别走了 f，s 步，则有：
# fast 走的步数是slow步数的 22 倍，即 f=2s；（解析： fast 每轮走 2 步）
# fast 比 slow多走了 n 个环的长度，即 f=s+nb；（ 解析： 双指针都走过 a 步，然后在环内绕圈直到重合，重合时 fast 比 slow 多走n环的长度整数倍 ）；
# 以上两式相减得：f=2nb，s=nb，即fast和slow 指针分别走了 2n，n 个 环的周长 （注意： n 是未知数，不同链表的情况不同）。\
# **目前情况分析：**
#
# 如果让指针从链表头部一直向前走并统计步数k，那么所有 走到链表入口节点时的步数 是：k=a+nb（先走 a 步到入口节点，之后每绕 1 圈环（ b 步）都会再次到入口节点）。
# 而目前，slow 指针走过的步数为 nb 步。因此，我们只要想办法让 slow 再走 a 步停下来，就可以到环的入口。
# 但是我们不知道 a 的值，该怎么办？依然是使用双指针法。我们构建一个指针，此指针需要有以下性质：此指针和slow 一起向前走 a 步后，两者在入口节点重合。那么从哪里走到入口节点需要 a 步？答案是链表头部head。\
# **双指针第二次相遇：**
#
# slow指针 位置不变 ，将fast指针重新 指向链表头部节点 ；slow和fast同时每轮向前走 1 步；
# TIPS：此时 f=0，s=nb;
# 当 fast 指针走到f=a 步时，slow 指针走到步s=a+nb，此时 两指针重合，并同时指向链表环入口。
# 返回slow指针指向的节点。

# %%
# Leetcode 142 环形链表
# 执行用时：56 ms, 在所有 Python3 提交中击败了50.48%的用户
# 内存消耗：18.6 MB, 在所有 Python3 提交中击败了51.20%的用户
# 时间复杂度O(n), 空间复杂度O(1)

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def detectCycle(self, head: ListNode) -> ListNode:
        if not head:
            return None
        fast, slow = head, head
        cycle_exist = False
        while fast.next and fast.next.next:
            fast = fast.next.next
            slow = slow.next
            if slow == fast:
                cycle_exist = True
                break
        if cycle_exist:
            slow = head
            while fast != slow:
                fast = fast.next
                slow = slow.next
            return slow
        return None

# %%
# Leetcode 160.1 相交链表，双指针
# 执行用时：140 ms, 在所有 Python3 提交中击败了78.71%的用户
# 内存消耗：29.8 MB, 在所有 Python3 提交中击败了53.05%的用户
# 时间复杂度O(m+n), 空间复杂度O(1)

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def getIntersectionNode(self, headA: ListNode, headB: ListNode) -> ListNode:
        if not headA or not headB:
            return None
        pa, pb = headA, headB
        while pa != pb:
            pa = pa.next if pa  else headB
            pb = pb.next if pb else headA
        return pa

# %%
# Leetcode 160.2 相交链表，双指针,计算长度的方法
# 执行用时：144 ms, 在所有 Python3 提交中击败了67.16%的用户
# 内存消耗：29.9 MB, 在所有 Python3 提交中击败了36.42%的用户
# 时间复杂度O(m+n), 空间复杂度O(1)

# note: 注意到底是not p1 还是 p1 在条件判断语句里

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def getIntersectionNode(self, headA: ListNode, headB: ListNode) -> ListNode:
        p1, p2 = headA, headB
        la, lb, length = 0, 0, 0
        while p1:
            p1 = p1.next
            la += 1
        while p2:
            p2 =  p2.next
            lb += 1
        if la > lb:
            p1 = headA
            p2 = headB
            length = la - lb
        else:
            p1 = headB
            p2 = headA
            length = lb - la
        for i in range(length):
            p1 = p1.next
        while p1 and p2:
            if p1 == p2:
                return p1
            p1 = p1.next
            p2 = p2.next
        return None

# %%
# Leetcode 160.3和4 相交链表，hashmap 和 穷举的方法

# %%
# Leetcode 206 反转链表，双指针
# 执行用时：40 ms, 在所有 Python3 提交中击败了61.77%的用户
# 内存消耗：16 MB, 在所有 Python3 提交中击败了75.87%的用户
# 时间复杂度O(n), 空间复杂度O(1)

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseList(self, head: ListNode) -> ListNode:
        curr, pre = head, None
        while curr:
            next = curr.next # Node
            curr.next = pre
            pre = curr
            curr = next
        return pre

# %%
# Leetcode 234 回文链表，快慢双指针 + 反转链表函数
# 执行用时：572 ms, 在所有 Python3 提交中击败了96.12%的用户
# 内存消耗：32.8 MB, 在所有 Python3 提交中击败了95.77%的用户
# 时间复杂度O(n), 空间复杂度O(1)

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseList(self, head: ListNode) -> ListNode:
        curr, pre = head, None
        while curr:
            next = curr.next # Node
            curr.next = pre
            pre = curr
            curr = next
        return pre

    def isPalindrome(self, head: ListNode) -> bool:
        fast, slow = head, head
        if fast and fast.next:
            fast = fast.next.next
            slow = slow.next
        # fast == None : n mod 2 == 0; fast != None and fast.next == None, n mod 2 == 1
        if fast:
            slow = slow.next
        slow = self.reverseList(slow)
        fast = head
        while slow and fast:
            if fast.val == slow.val:
                fast = fast.next
                slow = slow.next
            else:
                return False
        return True

# %%
# Leetcode 876 链表的中间节点，快慢双指针
# 执行用时：36 ms, 在所有 Python3 提交中击败了64.03%的用户
# 内存消耗：14.8 MB, 在所有 Python3 提交中击败了95.74%的用户
# 时间复杂度O(n), 空间复杂度O(1)

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def middleNode(self, head: ListNode) -> ListNode:
        fast, slow = head, head
        while fast and fast.next:
            fast = fast.next.next
            slow = slow.next
        return slow

# %%
# 剑指offer 22 链表中倒数第k个节点
# 1. hashmap
# 2. 先计算长度，再用n-k+1
# 3. 前后双指针

class Solution:
    def LastKNode(self, head: ListNode, k) -> ListNode:
        if k <= 0 or not head:
            return None
        fast, slow = head, None
        for i in range(k-1):
            if fast:
                fast = fast.next
        while fast:
            if not slow:
                slow = head
            else:
                slow = slow.next
            fast = fast.next
        if slow:
            return slow
        return None

# %% [markdown]
# #### 3. 栈与队列

# %%
# Leetcode 876 链表的中间节点，快慢双指针
# 执行用时：28 ms, 在所有 Python3 提交中击败了95.93%的用户
# 内存消耗：14.1 MB, 在所有 Python3 提交中击败了43.02%的用户

# list_type.pop([index=-1])，返回被删除的元素，默认删除index=-1的元素，此时list_type会变为list_type[:-1]

class MyQueue:

    def __init__(self):
        self.stack1 = []
        self.stack2 = []

    def push(self, x: int) -> None:
        self.stack1.append(x)

    def pop(self) -> int:
        if not self.stack2:
            while self.stack1:
                self.stack2.append(self.stack1.pop()) # list自带pop方法, stack1.pop()返回被删除元素，stack1则删除了该元素
        return self.stack2.pop()

    def peek(self) -> int:
        if not self.stack2:
            while self.stack1:
                self.stack2.append(self.stack1.pop())
        return self.stack2[-1]


    def empty(self) -> bool:
        return not self.stack1 and not self.stack2

# %%
# Leetcode 394 字符串解码，栈
# 执行用时：28 ms, 在所有 Python3 提交中击败了95.12%的用户
# 内存消耗：15 MB, 在所有 Python3 提交中击败了51.66%的用户

# 太难了太难了，感觉非常tricky

class Solution:
    def decodeString(self, s: str) -> str:
        stack, res, multi = [], '', 0
        for c in s:
            if c >= '0' and c <= '9':
                multi = multi * 10 + int(c)
            elif c == '[':
                stack.append([multi, res])
                multi, res = 0, ''
            elif c == ']':
                curr_multi, last_res = stack.pop()
                res = last_res + curr_multi * res
            else:
                res += c
        return res

# %% [markdown]
# ### 树

# %%
# Leetcode 94 中序遍历二叉树，递归
# 执行用时：28 ms, 在所有 Python3 提交中击败了95.92%的用户
# 内存消耗：14.9 MB, 在所有 Python3 提交中击败了64.66%的用户
# 时间复杂度: O(n), 空间复杂度: O(n)

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def inorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        res = []
        self.inOrder(root, res)
        return res

    def inOrder(self, root:TreeNode, res):
        if root == None:
            return
        self.inOrder(root.left, res)
        res.append(root.val)
        self.inOrder(root.right, res)

# %%
# Leetcode 94 中序遍历二叉树，栈
# 执行用时：40 ms, 在所有 Python3 提交中击败了36.42%的用户
# 内存消耗：15 MB, 在所有 Python3 提交中击败了12.56%的用户

# 已经神志不清了

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def inorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        res, stack = [], []
        while root or len(stack) > 0:
            while root:
                stack.append(root)
                root = root.left
            root = stack.pop()
            res.append(root.val)
            root = root.right
        return res

# %%
# Leetcode 144 前序遍历二叉树，递归
# 执行用时：36 ms, 在所有 Python3 提交中击败了65.33%的用户
# 内存消耗：14.9 MB, 在所有 Python3 提交中击败了49.58%的用户
# 时间复杂度：O(n), 空间复杂度: O(n)

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        res = []
        self.preOrder(root, res)
        return res

    def preOrder(self, root:TreeNode, res:List):
        if root== None:
            return
        res.append(root.val)
        self.preOrder(root.left, res)
        self.preOrder(root.right, res)
        return res

# %%
# Leetcode 144 前序遍历二叉树，循环，栈
# 执行用时：40 ms, 在所有 Python3 提交中击败了36.59%的用户
# 内存消耗：14.9 MB, 在所有 Python3 提交中击败了58.68%的用户

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        res, stack = [], []
        while root or len(stack)>0:
            while root:
                res.append(root.val)
                stack.append(root)
                root = root.left
            root = stack.pop()
            root = root.right
        return res

# %%
# Leetcode 145 后序遍历二叉树，递归
# 执行用时：32 ms, 在所有 Python3 提交中击败了86.53%的用户
# 内存消耗：14.9 MB, 在所有 Python3 提交中击败了45.83%的用户

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def postorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        res = []
        self.postOrder(root, res)
        return res

    def postOrder(self, root:TreeNode, res:TreeNode):
        if root == None:
            return
        self.postOrder(root.left, res)
        self.postOrder(root.right, res)
        res.append(root.val)

# %%
# Leetcode 145 后序遍历二叉树，循环，栈
# 执行用时：36 ms, 在所有 Python3 提交中击败了65.82%的用户
# 内存消耗：14.8 MB, 在所有 Python3 提交中击败了95.43%的用户

# 麻了麻了，again

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def postorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        res, stack = [], []
        preAccess = None
        while root or len(stack) > 0:
            while root:
                stack.append(root)
                root = root.left
            root = stack.pop()
            if root.right == None or root.right == preAccess:
                res.append(root.val)
                preAccess = root
                root = None
            else:
                stack.append(root)
                root = root.right
        return res
